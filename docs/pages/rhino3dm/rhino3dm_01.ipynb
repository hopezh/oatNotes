# %% [markdown]
# # rhino3dm exercise 01
#
# # test reading geometry by layer name

# %%
import rhino3dm

model = rhino3dm.File3dm.Read('./data/oat_model.3dm')
print('model object: ', model)
print('------')

layer_table = model.Layers
print('layer table: ', layer_table, '\n')

for idx, layer in enumerate(iter(layer_table)):
    print('layer ', idx, ' object  : ', layer)
    print('      ', idx, ' id      : ', layer.Id)
    print('      ', idx, ' index   : ', layer.Index)
    print('      ', idx, ' name    : ', layer.Name)
    print('      ', idx, ' fullpath: ', layer.FullPath)

print('------')

object_table = model.Objects
print('object table: ', object_table, '\n')

for idx, object in enumerate(iter(object_table)):
    print('object ', idx, ' object    : ', object)
    print('       ', idx, ' geometry  : ', object.Geometry)
    print('       ', idx, ' attributes: ', object.Attributes)
    print('       ', idx, ' layerIndex: ', object.Attributes.LayerIndex)

print('------')


# brep = model.Objects[0].Geometry
# face = brep.Faces[0]
# mesh = face.GetMesh(rhino3dm.MeshType.Any)
# print (len(mesh.Faces))
# Out:
# model object:  <rhino3dm._rhino3dm.File3dm object at 0x0000015BADFCA7F0>
# ------
# layer table:  <rhino3dm._rhino3dm.File3dmLayerTable object at 0x0000015BABE92AB0>
#
# layer  0  object  :  <rhino3dm._rhino3dm.Layer object at 0x0000015BADFCAA30>
#        0  id      :  212960d6-ad46-439d-8516-772ce85fde03
#        0  index   :  0
#        0  name    :  Default
#        0  fullpath:  Default
# layer  1  object  :  <rhino3dm._rhino3dm.Layer object at 0x0000015BADFCAFB0>
#        1  id      :  430ce6c7-13d8-40d9-ae38-08e0e7d0f1df
#        1  index   :  1
#        1  name    :  layer_1
#        1  fullpath:  layer_1
# layer  2  object  :  <rhino3dm._rhino3dm.Layer object at 0x0000015BADFCBA30>
#        2  id      :  8e04c4aa-0bcb-4331-9ac1-79ed7bacc9f1
#        2  index   :  2
#        2  name    :  b_1
#        2  fullpath:  layer_1::b_1
# layer  3  object  :  <rhino3dm._rhino3dm.Layer object at 0x0000015BADFCB530>
#        3  id      :  906c125d-ea30-483a-bf45-6fc769473e09
#        3  index   :  3
#        3  name    :  s_1
#        3  fullpath:  layer_1::s_1
# layer  4  object  :  <rhino3dm._rhino3dm.Layer object at 0x0000015BADFC93F0>
#        4  id      :  1d1e5147-f5b7-4fa1-82ea-3ece64f5994c
#        4  index   :  4
#        4  name    :  layer_2
#        4  fullpath:  layer_2
# ------
# object table:  <rhino3dm._rhino3dm.File3dmObjectTable object at 0x0000015BADFCBDF0>
#
# object  0  object    :  <rhino3dm._rhino3dm.File3dmObject object at 0x0000015BADFCBD30>
#         0  geometry  :  <rhino3dm._rhino3dm.Brep object at 0x0000015BADFC8CF0>
#         0  attributes:  <rhino3dm._rhino3dm.ObjectAttributes object at 0x0000015BADFC8CF0>
#         0  layerIndex:  2
# object  1  object    :  <rhino3dm._rhino3dm.File3dmObject object at 0x0000015BADAC6CF0>
#         1  geometry  :  <rhino3dm._rhino3dm.Mesh object at 0x0000015BADFCBD30>
#         1  attributes:  <rhino3dm._rhino3dm.ObjectAttributes object at 0x0000015BADFCBD30>
#         1  layerIndex:  4
# object  2  object    :  <rhino3dm._rhino3dm.File3dmObject object at 0x0000015BADAC5530>
#         2  geometry  :  <rhino3dm._rhino3dm.Extrusion object at 0x0000015BADFCBD30>
#         2  attributes:  <rhino3dm._rhino3dm.ObjectAttributes object at 0x0000015BADFCBD30>
#         2  layerIndex:  3
# object  3  object    :  <rhino3dm._rhino3dm.File3dmObject object at 0x0000015BADAC5F30>
#         3  geometry  :  <rhino3dm._rhino3dm.Brep object at 0x0000015BADFCBD30>
#         3  attributes:  <rhino3dm._rhino3dm.ObjectAttributes object at 0x0000015BADFCBD30>
#         3  layerIndex:  2
# object  4  object    :  <rhino3dm._rhino3dm.File3dmObject object at 0x0000015BADAC75B0>
#         4  geometry  :  <rhino3dm._rhino3dm.Brep object at 0x0000015BADFCBD30>
#         4  attributes:  <rhino3dm._rhino3dm.ObjectAttributes object at 0x0000015BADFCBD30>
#         4  layerIndex:  2
# object  5  object    :  <rhino3dm._rhino3dm.File3dmObject object at 0x0000015BADAC79F0>
#         5  geometry  :  <rhino3dm._rhino3dm.Brep object at 0x0000015BADFCBD30>
#         5  attributes:  <rhino3dm._rhino3dm.ObjectAttributes object at 0x0000015BADFCBD30>
#         5  layerIndex:  2
# object  6  object    :  <rhino3dm._rhino3dm.File3dmObject object at 0x0000015BADAC6370>
#         6  geometry  :  <rhino3dm._rhino3dm.PolylineCurve object at 0x0000015BADFCBD30>
#         6  attributes:  <rhino3dm._rhino3dm.ObjectAttributes object at 0x0000015BADFCBD30>
#         6  layerIndex:  0
# ------

# %% [markdown]
# > **File3dm.Read()**
# >
# > [***method***
# > `rhino3dm.File3dm.Read()`](https://mcneel.github.io/rhino3dm/python/api/File3dm.html#rhino3dm.File3dm.Read)
# >
# > <br />
# >
# > Reads a `3dm` file from the specified path.
# >
# > <br />
# >
# > Parameters:
# >
# > -   path (str) – The file to read.
# >
# > Returns:
# >
# > -   new File3dm on success, None on error.
# >
# > Return type:
# >
# > -   File3dm
#
# > **File3dm.Layers**
# >
# > [***attrib***
# > `rhino3dm.File3dm.Layer`](https://mcneel.github.io/rhino3dm/python/api/File3dm.html#rhino3dm.File3dm.Layers)
# >
# > <br />
# >
# > IList<Layer>: Layers in this file.
# >
# > <br />
# >
# > Returns:
# >
# > -   File3dmLayerTable
#
# > **File3dmLayerTable**
# >
# > [***class***
# > `rhino3dm.File3dmLayerTable`](https://mcneel.github.io/rhino3dm/python/api/File3dmLayerTable.html#module-rhino3dm)
# >
# > <br />
# >
# > Each item is a `rhino3dm.Layer` object
# >
# > <br />
# >
# > Methods:
# >
# > -   \_\_getitem\_\_()
# > -   \_\_iter\_\_()
# > -   \_\_len\_\_()
# > -   …
#
# > **Layer**
# >
# > [***class***
# > `rhino3dm.Layer`](https://mcneel.github.io/rhino3dm/python/api/Layer.html#module-rhino3dm)
# >
# > <br />
# >
# > Attributes:
# >
# > -   Color
# > -   FullPath
# > -   Id
# > -   Index
# > -   Locked
# > -   Name
# > -   ParentLayerId
# > -   Visible
# > -   …
#
# > **File3dm.Objects**
# >
# > [***attrib***
# > `rhino3dm.File3dm.Objects`](https://mcneel.github.io/rhino3dm/python/api/File3dm.html#rhino3dm.File3dm.Objects)
# >
# > <br />
# >
# > Returns a `File3dmObjectTable`: Gets access to the class associated
# > with this file, which contains all objects.
#
# > **File3dmObjectTable**
# >
# > [***class***
# > `rhino3dm.File3dmObjectTable`](https://mcneel.github.io/rhino3dm/python/api/File3dmObjectTable.html#module-rhino3dm)
# >
# > <br />
# >
# > Each item is a `rhino3dm.Object` object
# >
# > <br />
# >
# > Methods:
# >
# > -   \_\_getitem\_\_()
# > -   \_\_iter\_\_()
# > -   \_\_len\_\_()
# > -   …
#
# > **File3dmObject**
# >
# > [***class***
# > `rhino3dm.File3dmObject`](https://mcneel.github.io/rhino3dm/python/api/File3dmObject.html#module-rhino3dm)
# >
# > <br />
# >
# > Attribs:
# >
# > -   Attributes
# >     -   `ObjectAttributes`: Gets the attributes that are linked with
# >         this document object.
# > -   Geometry
# >     -   `rhino3dm.GeometryBase`: Gets the geometry that is linked with
# >         this document object.
#
# > **ObjectAttributes**
# >
# > [***class***
# > `rhino3dm.ObjectAttributes`](https://mcneel.github.io/rhino3dm/python/api/ObjectAttributes.html#module-rhino3dm)
# >
# > <br />
# >
# > Attribs:
# >
# > -   Id
# > -   LayerIndex
# > -   MaterialIndex
# > -   Name
# > -   ObjectColor
# > -   Visible
# > -   …
#
# > **GeomtryBase**
# >
# > [***class***
# > `rhino3dm.GeometryBase`](https://mcneel.github.io/rhino3dm/python/api/GeometryBase.html#module-rhino3dm)
# >
# > <br />
# >
# > Attribs:
# >
# > -   ObjectType
# > -   …
